# %% [markdown]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ER диаграмма
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Логическая схема
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Роль admin
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Таблица преподователей
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Таблицы по успеваемости в дисциплине(такой порядок во всех дисциплинах)
#
# ![image.png](attachment:image.png)
