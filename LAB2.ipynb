# %% [markdown]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ER Диаграмма
# ![image.png](attachment:image.png)

# %% [markdown]
# Логическая схема учета преподавателей и успеваемости
# ![image.png](attachment:image.png)

# %% [markdown]
# Роль admin
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Схема самих таблиц с разными ситуациями
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Схемы на языке SQL(SQL файлы подкреплены)
# Успеваемость по мат анализу группы ИВТ-22
# ![image.png](attachment:image.png)
# Дисциплины и группы  Сидорова В.А
# ![image-2.png](attachment:image-2.png)
