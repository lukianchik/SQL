# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Таблица с отделами в компании
# ![image.png](attachment:image.png)

# %% [markdown]
# Таблица с сотрудниками в компании
# ![image.png](attachment:image.png)

# %% [markdown]
# Зарплата каждого сотрудника в месяц
# ![image-2.png](attachment:image-2.png)
#
# Количество строк в таблице (15 сотрудников * 12 месяцев = 180)
# ![image.png](attachment:image.png)

# %% [markdown]
# Средняя зарплата в отделе продаж
#
# ![image-2.png](attachment:image-2.png)
#
# (100 + 80 + 50 + 50)/ 4 * 1000 = 70_000
# ![image.png](attachment:image.png)

# %% [markdown]
# Средняя зарплата в отделе рекламы
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Средняя зарплата в бухгалтерии
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Средняя зарплата в ИТ отделе
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# id_employee руководителей = 1, 5, 8, 11
# ![image-2.png](attachment:image-2.png)
#
# Средняя зарплата руководителей
# ![image.png](attachment:image.png)

# %% [markdown]
# Максимальная зарплата у CEO, минимальная у обычного специалиста в продажах или бухгалтерии
# ![image.png](attachment:image.png)
